# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, optimizers, Sequential, metrics
import matplotlib.pyplot as plt
import  io
import  datetime
(x, y), (test_x, test_y) = datasets.cifar10.load_data()
 
# 数据预处理
def progress (x ,y):
    x = 2 * tf.cast(x, dtype=tf.float32) / 255.
    x = tf.reshape(x, [-1, 32*32*3])
    y = tf.one_hot(y, depth=10, dtype=tf.int32)
    return x, y
# 构建dataset对象 方便对数据的管理,它的作用是把给定的元组、列表和张量等数据进行特征切片
db_train = tf.data.Dataset.from_tensor_slices((x,y)).shuffle(1000)
db_test = tf.data.Dataset.from_tensor_slices((test_x,test_y))
# deal with data
train_db = db_train.map(progress).batch(128)
test_db = db_test.map(progress).batch(128)
 
# 利用Tensorflow的Sequential容器去构建model
model = Sequential([
    layers.Dense(64, activation=tf.nn.relu),
    layers.Dense(32, activation=tf.nn.relu),
    layers.Dense(10)
])
model.build(input_shape=[None, 32*32*3])
model.summary()
 
#利用Sequential的compile方法，简化损失函数(交叉熵损失函数），梯度优化，计算准确率等操作 
model.compile(optimizer=optimizers.Adam(lr = 0.01),
              loss = tf.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy']
              )
# 设置模型对整体数据重复训练5次，每训练2次打印一次正确率
model.fit(train_db, epochs=60, validation_data = test_db,
              verbose=2)
# 另一种打印模型正确率的接口方法
# model.evaluate(test_db)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  196672
# _________________________________________________________________
# dense_1 (Dense)              multiple                  2080
# _________________________________________________________________
# dense_2 (Dense)              multiple                  330
# =================================================================
# Total params: 199,082
# Trainable params: 199,082
# Non-trainable params: 0
# _________________________________________________________________
# Train for 391 steps, validate for 79 steps
# Epoch 1/60
# 391/391 - 19s - loss: 2.4882 - accuracy: 0.1628 - val_loss: 2.1021 - val_accuracy: 0.1770
# Epoch 2/60
# 391/391 - 15s - loss: 2.0759 - accuracy: 0.1867 - val_loss: 2.0895 - val_accuracy: 0.1894
# Epoch 3/60
# 391/391 - 15s - loss: 2.0533 - accuracy: 0.1890 - val_loss: 2.0385 - val_accuracy: 0.2033
# Epoch 4/60
# 391/391 - 15s - loss: 2.0083 - accuracy: 0.2181 - val_loss: 1.9120 - val_accuracy: 0.2637
# Epoch 5/60
# 391/391 - 16s - loss: 1.8821 - accuracy: 0.2868 - val_loss: 1.8348 - val_accuracy: 0.3003
# Epoch 6/60
# 391/391 - 16s - loss: 1.8460 - accuracy: 0.3109 - val_loss: 1.8912 - val_accuracy: 0.3058
# Epoch 7/60
# 391/391 - 16s - loss: 1.8169 - accuracy: 0.3276 - val_loss: 1.7883 - val_accuracy: 0.3345
# Epoch 8/60
# 391/391 - 15s - loss: 1.7888 - accuracy: 0.3408 - val_loss: 1.8809 - val_accuracy: 0.2861
# Epoch 9/60
# 391/391 - 16s - loss: 1.7726 - accuracy: 0.3464 - val_loss: 1.7832 - val_accuracy: 0.3368
# Epoch 10/60
# 391/391 - 15s - loss: 1.7616 - accuracy: 0.3595 - val_loss: 1.7557 - val_accuracy: 0.3592
# Epoch 11/60
# 391/391 - 15s - loss: 1.7443 - accuracy: 0.3667 - val_loss: 1.7194 - val_accuracy: 0.3767
# Epoch 12/60
# 391/391 - 15s - loss: 1.7384 - accuracy: 0.3686 - val_loss: 1.7256 - val_accuracy: 0.3671
# Epoch 13/60
# 391/391 - 16s - loss: 1.7253 - accuracy: 0.3737 - val_loss: 1.7064 - val_accuracy: 0.3821
# Epoch 14/60
# 391/391 - 15s - loss: 1.7295 - accuracy: 0.3733 - val_loss: 1.7280 - val_accuracy: 0.3719
# Epoch 15/60
# 391/391 - 16s - loss: 1.7136 - accuracy: 0.3762 - val_loss: 1.6909 - val_accuracy: 0.3813
# Epoch 16/60
# 391/391 - 15s - loss: 1.6978 - accuracy: 0.3824 - val_loss: 1.7126 - val_accuracy: 0.3788
# Epoch 17/60
# 391/391 - 15s - loss: 1.7253 - accuracy: 0.3737 - val_loss: 1.7385 - val_accuracy: 0.3633
# Epoch 18/60
# 391/391 - 16s - loss: 1.6973 - accuracy: 0.3819 - val_loss: 1.7308 - val_accuracy: 0.3677
# Epoch 19/60
# 391/391 - 15s - loss: 1.7006 - accuracy: 0.3819 - val_loss: 1.6885 - val_accuracy: 0.3921
# Epoch 20/60
# 391/391 - 17s - loss: 1.6958 - accuracy: 0.3814 - val_loss: 1.7157 - val_accuracy: 0.3798
# Epoch 21/60
# 391/391 - 16s - loss: 1.7012 - accuracy: 0.3806 - val_loss: 1.7348 - val_accuracy: 0.3702
# Epoch 22/60
# 391/391 - 15s - loss: 1.6837 - accuracy: 0.3860 - val_loss: 1.7140 - val_accuracy: 0.3685
# Epoch 23/60
# 391/391 - 16s - loss: 1.6847 - accuracy: 0.3845 - val_loss: 1.7340 - val_accuracy: 0.3695
# Epoch 24/60
# 391/391 - 16s - loss: 1.6820 - accuracy: 0.3875 - val_loss: 1.6877 - val_accuracy: 0.3862
# Epoch 25/60
# 391/391 - 16s - loss: 1.6798 - accuracy: 0.3851 - val_loss: 1.6833 - val_accuracy: 0.3878
# Epoch 26/60
# 391/391 - 16s - loss: 1.6772 - accuracy: 0.3870 - val_loss: 1.7274 - val_accuracy: 0.3747
# Epoch 27/60
# 391/391 - 15s - loss: 1.6791 - accuracy: 0.3858 - val_loss: 1.6946 - val_accuracy: 0.3849
# Epoch 28/60
# 391/391 - 15s - loss: 1.6742 - accuracy: 0.3892 - val_loss: 1.6920 - val_accuracy: 0.3839
# Epoch 29/60
# 391/391 - 15s - loss: 1.6769 - accuracy: 0.3893 - val_loss: 1.7120 - val_accuracy: 0.3681
# Epoch 30/60
# 391/391 - 15s - loss: 1.6685 - accuracy: 0.3894 - val_loss: 1.7173 - val_accuracy: 0.3727
# Epoch 31/60
# 391/391 - 15s - loss: 1.6705 - accuracy: 0.3891 - val_loss: 1.7654 - val_accuracy: 0.3685
# Epoch 32/60
# 391/391 - 15s - loss: 1.6658 - accuracy: 0.3908 - val_loss: 1.7055 - val_accuracy: 0.3762
# Epoch 33/60
# 391/391 - 15s - loss: 1.6653 - accuracy: 0.3880 - val_loss: 1.6961 - val_accuracy: 0.3907
# Epoch 34/60
# 391/391 - 16s - loss: 1.6614 - accuracy: 0.3936 - val_loss: 1.7076 - val_accuracy: 0.3891
# Epoch 35/60
# 391/391 - 16s - loss: 1.6563 - accuracy: 0.3953 - val_loss: 1.7236 - val_accuracy: 0.3731
# Epoch 36/60
# 391/391 - 15s - loss: 1.6600 - accuracy: 0.3919 - val_loss: 1.6940 - val_accuracy: 0.3925
# Epoch 37/60
# 391/391 - 16s - loss: 1.6643 - accuracy: 0.3927 - val_loss: 1.7256 - val_accuracy: 0.3694
# Epoch 38/60
# 391/391 - 16s - loss: 1.6613 - accuracy: 0.3923 - val_loss: 1.7261 - val_accuracy: 0.3786
# Epoch 39/60
# 391/391 - 17s - loss: 1.6626 - accuracy: 0.3898 - val_loss: 1.7397 - val_accuracy: 0.3605
# Epoch 40/60
# 391/391 - 17s - loss: 1.6547 - accuracy: 0.3939 - val_loss: 1.7326 - val_accuracy: 0.3753
# Epoch 41/60
# 391/391 - 17s - loss: 1.6535 - accuracy: 0.3953 - val_loss: 1.7363 - val_accuracy: 0.3690
# Epoch 42/60
# 391/391 - 18s - loss: 1.6532 - accuracy: 0.3951 - val_loss: 1.6842 - val_accuracy: 0.3895
# Epoch 43/60
# 391/391 - 18s - loss: 1.6502 - accuracy: 0.3967 - val_loss: 1.6899 - val_accuracy: 0.3795
# Epoch 44/60
# 391/391 - 17s - loss: 1.6454 - accuracy: 0.4000 - val_loss: 1.6805 - val_accuracy: 0.3928
# Epoch 45/60
# 391/391 - 17s - loss: 1.6420 - accuracy: 0.3968 - val_loss: 1.7324 - val_accuracy: 0.3701
# Epoch 46/60
# 391/391 - 18s - loss: 1.6446 - accuracy: 0.3983 - val_loss: 1.6730 - val_accuracy: 0.3912
# Epoch 47/60
# 391/391 - 18s - loss: 1.6432 - accuracy: 0.3985 - val_loss: 1.6704 - val_accuracy: 0.3993
# Epoch 48/60
# 391/391 - 18s - loss: 1.6408 - accuracy: 0.3997 - val_loss: 1.7019 - val_accuracy: 0.3781
# Epoch 49/60
# 391/391 - 18s - loss: 1.6365 - accuracy: 0.4028 - val_loss: 1.7114 - val_accuracy: 0.3797
# Epoch 50/60
# 391/391 - 17s - loss: 1.6406 - accuracy: 0.3983 - val_loss: 1.6969 - val_accuracy: 0.3893
# Epoch 51/60
# 391/391 - 17s - loss: 1.6450 - accuracy: 0.3998 - val_loss: 1.7116 - val_accuracy: 0.3788
# Epoch 52/60
# 391/391 - 16s - loss: 1.6341 - accuracy: 0.4034 - val_loss: 1.7161 - val_accuracy: 0.3788
# Epoch 53/60
# 391/391 - 18s - loss: 1.6348 - accuracy: 0.4037 - val_loss: 1.7073 - val_accuracy: 0.3815
# Epoch 54/60
# 391/391 - 17s - loss: 1.6468 - accuracy: 0.3959 - val_loss: 1.7590 - val_accuracy: 0.3514
# Epoch 55/60
# 391/391 - 16s - loss: 1.6384 - accuracy: 0.3987 - val_loss: 1.7275 - val_accuracy: 0.3793
# Epoch 56/60
# 391/391 - 17s - loss: 1.6396 - accuracy: 0.4014 - val_loss: 1.6924 - val_accuracy: 0.3873
# Epoch 57/60
# 391/391 - 16s - loss: 1.6293 - accuracy: 0.4049 - val_loss: 1.7279 - val_accuracy: 0.3787
# Epoch 58/60
# 391/391 - 17s - loss: 1.6374 - accuracy: 0.3995 - val_loss: 1.6969 - val_accuracy: 0.3948
# Epoch 59/60
# 391/391 - 16s - loss: 1.6389 - accuracy: 0.3996 - val_loss: 1.7249 - val_accuracy: 0.3655
# Epoch 60/60
# 391/391 - 15s - loss: 1.6235 - accuracy: 0.4075 - val_loss: 1.7463 - val_accuracy: 0.3669

# %%
model.evaluate(test_db)
# Out:
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7300 - accuracy: 0.3674
# [1.7300352220293842, 0.3674]
